# %%
import pandas as pd
df = pd.read_csv("../data/raw.csv")
print(df.head())
print(df.columns)
print(df.info())
print(df.isna().sum())
# Out:
#   Demographic dependency ratio;"761";"Helsinki";"091";"combined";1990;41.6;
# 0  Demographic dependency ratio;"761";"Helsinki";...
# 1  Demographic dependency ratio;"761";"Helsinki";...
# 2  Demographic dependency ratio;"761";"Helsinki";...
# 3  Demographic dependency ratio;"761";"Helsinki";...
# 4  Demographic dependency ratio;"761";"Helsinki";...
# Index(['Demographic dependency ratio;"761";"Helsinki";"091";"combined";1990;41.6;'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 1 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   Demographic dependency ratio;"761";"Helsinki";"091";"combined";1990;41.6;  804 non-null    object
# dtypes: object(1)
# memory usage: 6.4+ KB
# None
# ...
